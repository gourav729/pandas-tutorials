# %%
import pandas as pd

# %%
df = pd.read_csv('F:/project/pandas_tutorials series/data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('F:/project/pandas_tutorials series/data/survey_results_schema.csv', index_col='Column')

# %%
df.shape
# Out:
# (88883, 84)

# %%
# df.info()
#a long list so did not run the result

# %%
# to view all the 85 columns
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 20)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  ...  \
# Respondent                                                     ...
# 1           Taught yourself a new language, framework, or ...  ...
# 2           Taken an online course in programming or softw...  ...
# 3           Taught yourself a new language, framework, or ...  ...
# 4           Taken an online course in programming or softw...  ...
# 5           Taken an online course in programming or softw...  ...
#
#                                       WelcomeChange  \
# Respondent
# 1           Just as welcome now as I felt last year
# 2           Just as welcome now as I felt last year
# 3           Just as welcome now as I felt last year
# 4           Just as welcome now as I felt last year
# 5           Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
#
# [5 rows x 84 columns]

# %%
df.tail()
# Out:
#            MainBranch Hobbyist  \
# Respondent
# 88377             NaN      Yes
# 88601             NaN       No
# 88802             NaN       No
# 88816             NaN       No
# 88863             NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 88377       Less than once a month but more than once per ...
# 88601                                                   Never
# 88802                                                   Never
# 88816                                                   Never
# 88863                                 Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 88377       The quality of OSS and closed source software ...
# 88601       The quality of OSS and closed source software ...
# 88802                                                     NaN
# 88816       OSS is, on average, of HIGHER quality than pro...
# 88863       OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment Country  \
# Respondent
# 88377                  Not employed, and not looking for work  Canada
# 88601                                                     NaN     NaN
# 88802                                      Employed full-time     NaN
# 88816       Independent contractor, freelancer, or self-em...     NaN
# 88863                  Not employed, and not looking for work   Spain
#
#                    Student                             EdLevel  \
# Respondent
# 88377                   No           Primary/elementary school
# 88601                  NaN                                 NaN
# 88802                  NaN                                 NaN
# 88816                  NaN                                 NaN
# 88863       Yes, full-time  Professional degree (JD, MD, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 88377                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
# 88863       Computer science, computer engineering, or sof...
#
#                                                      EduOther  ...  \
# Respondent                                                     ...
# 88377       Taught yourself a new language, framework, or ...  ...
# 88601                                                     NaN  ...
# 88802                                                     NaN  ...
# 88816                                                     NaN  ...
# 88863       Taken an online course in programming or softw...  ...
#
#                                        WelcomeChange  \
# Respondent
# 88377                                            NaN
# 88601                                            NaN
# 88802                                            NaN
# 88816                                            NaN
# 88863       Somewhat less welcome now than last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 88377       Tech articles written by other developers;Tech...   NaN    Man
# 88601                                                     NaN   NaN    NaN
# 88802                                                     NaN   NaN    NaN
# 88816                                                     NaN   NaN    NaN
# 88863       Tech articles written by other developers;Indu...  18.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 88377         No                      NaN
# 88601        NaN                      NaN
# 88802        NaN                      NaN
# 88816        NaN                      NaN
# 88863         No  Straight / Heterosexual
#
#                                                     Ethnicity Dependents  \
# Respondent
# 88377                                                     NaN         No
# 88601                                                     NaN        NaN
# 88802                                                     NaN        NaN
# 88816                                                     NaN        NaN
# 88863       Hispanic or Latino/Latina;White or of European...         No
#
#                      SurveyLength SurveyEase
# Respondent
# 88377       Appropriate in length       Easy
# 88601                         NaN        NaN
# 88802                         NaN        NaN
# 88816                         NaN        NaN
# 88863       Appropriate in length       Easy
#
# [5 rows x 84 columns]

# %%
#Selecting rows and columns
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
# using iloc uses only integers
df.iloc[0]
df.iloc[0:4]

#for cols
df.iloc[0, 2]
df.iloc[0:4, 1:3]
# Out:
#            Hobbyist              OpenSourcer
# Respondent
# 1               Yes                    Never
# 2                No  Less than once per year
# 3               Yes                    Never
# 4                No                    Never

# %%
# #using loc which uses labels
# #indexing is inclusive
# df.loc[0]
# df.loc[0, 'Hobbyist']
# df.loc[0:3, 'Hobbyist':'Employment']

# %% [markdown]
# ### set, reset and sort index
# #### df.set_index('email')
# #### df.set_index('email', implace=True) for permanent changes
# #### df.reset_index(inplace=True)
# #### df.sort()
# #### df.sort(ascending=False)

# %%
schema_df.loc['Hobbyist']
schema_df.loc['Hobbyist', 'QuestionText']
# Out:
# 'Do you code as a hobby?'

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                     QuestionText
# Column
# YearsCodePro   How many years have you coded professionally (...
# YearsCode      Including any education, how many years have y...
# WorkWeekHrs     On average, how many hours per week do you work?
# WorkRemote                       How often do you work remotely?
# WorkPlan                 How structured or planned is your work?
# ...                                                          ...
# BlockchainOrg  How is your organization thinking about or imp...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BetterLife     Do you think people born today will have a bet...
# Age1stCode     At what age did you write your first line of c...
# Age            What is your age (in years)? If you prefer not...
#
# [85 rows x 1 columns]

# %%
schema_df.sort_index(inplace=True)
schema_df
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %% [markdown]
# ### filtering data also use & |

# %%
high_salary = ((df['ConvertedComp'] > 70000))
high_salary
# Out:
# Respondent
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: ConvertedComp, Length: 88883, dtype: bool

# %%
df.loc[high_salary]
df.loc[high_salary, ['Country', 'LanguagesWorkedWith', 'ConvertedComp']]
# Out:
#                    Country  LanguagesWorkedWith  ConvertedComp
# Respondent
# 6                   Canada                  NaN       366420.0
# 9              New Zealand                  NaN        95179.0
# 13           United States                  NaN        90000.0
# 16          United Kingdom                  NaN       455352.0
# 22           United States                  NaN       103000.0
# ...                    ...                  ...            ...
# 88876        United States                  NaN       180000.0
# 88877        United States                  NaN      2000000.0
# 88878        United States                  NaN       130000.0
# 88879              Finland                  NaN        82488.0
# 88882          Netherlands                  NaN       588012.0
#
# [22289 rows x 3 columns]

# %%
countries = ['United States', 'India', 'United Kingdom']
filt = df['Country'].isin(countries)

# %%
df.loc[filt]
df.loc[filt, 'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 8                 India
# 10                India
# 13        United States
#               ...
# 84539    United Kingdom
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# Name: Country, Length: 35747, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
# Apply, map, applymap and replace methods
df.rename(columns = {'ConvertedComp':'SalaryUSD'}, inplace=True)
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].replace({'Yes': True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
# Sorting Data
df.sort_values(by='Country', inplace=True)
df.head(50)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 39258                          I am a developer by profession      Yes
# 63129                          I am a developer by profession      Yes
# 85715                          I am a developer by profession       No
# 50767                          I am a developer by profession       No
# 2782                                                      NaN      Yes
# ...                                                       ...      ...
# 57419                          I am a developer by profession      Yes
# 49757                          I am a developer by profession      Yes
# 41608       I am not primarily a developer, but I write co...      Yes
# 33385                          I am a developer by profession      Yes
# 6716                           I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 39258                                 Less than once per year
# 63129                                                   Never
# 85715                                 Less than once per year
# 50767                                 Less than once per year
# 2782                                  Less than once per year
# ...                                                       ...
# 57419                                 Less than once per year
# 49757                                                   Never
# 41608                                 Less than once per year
# 33385                                 Less than once per year
# 6716        Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 39258       OSS is, on average, of LOWER quality than prop...
# 63129       OSS is, on average, of HIGHER quality than pro...
# 85715       The quality of OSS and closed source software ...
# 50767                                                     NaN
# 2782        OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 57419       The quality of OSS and closed source software ...
# 49757       OSS is, on average, of HIGHER quality than pro...
# 41608       OSS is, on average, of LOWER quality than prop...
# 33385       OSS is, on average, of LOWER quality than prop...
# 6716        OSS is, on average, of LOWER quality than prop...
#
#                                                    Employment      Country  \
# Respondent
# 39258                                      Employed full-time  Afghanistan
# 63129                                      Employed full-time  Afghanistan
# 85715                                      Employed full-time  Afghanistan
# 50767       Independent contractor, freelancer, or self-em...  Afghanistan
# 2782                                                      NaN  Afghanistan
# ...                                                       ...          ...
# 57419       Independent contractor, freelancer, or self-em...      Albania
# 49757                                      Employed full-time      Albania
# 41608                                      Employed full-time      Albania
# 33385                                      Employed full-time      Albania
# 6716        Independent contractor, freelancer, or self-em...      Albania
#
#                    Student                                            EdLevel  \
# Respondent
# 39258                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 63129       Yes, full-time             I never completed any formal education
# 85715                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 50767       Yes, part-time                                   Associate degree
# 2782                    No                                                NaN
# ...                    ...                                                ...
# 57419       Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 49757       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 41608       Yes, part-time  Some college/university study without earning ...
# 33385                  NaN                                                NaN
# 6716                    No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 39258       Computer science, computer engineering, or sof...
# 63129                                                     NaN
# 85715       Information systems, information technology, o...
# 50767       A health science (ex. nursing, pharmacy, radio...
# 2782                                 I never declared a major
# ...                                                       ...
# 57419       Computer science, computer engineering, or sof...
# 49757       Computer science, computer engineering, or sof...
# 41608       Computer science, computer engineering, or sof...
# 33385                                                     NaN
# 6716        A business discipline (ex. accounting, finance...
#
#                                                      EduOther  ...  \
# Respondent                                                     ...
# 39258       Taken an online course in programming or softw...  ...
# 63129       Taken an online course in programming or softw...  ...
# 85715       Received on-the-job training in software devel...  ...
# 50767       Completed an industry certification program (e...  ...
# 2782        Taken an online course in programming or softw...  ...
# ...                                                       ...  ...
# 57419       Taken an online course in programming or softw...  ...
# 49757       Taken an online course in programming or softw...  ...
# 41608       Taken an online course in programming or softw...  ...
# 33385                                                     NaN  ...
# 6716        Taken an online course in programming or softw...  ...
#
#                                                 WelcomeChange  \
# Respondent
# 39258                                                     NaN
# 63129                                                     NaN
# 85715                Somewhat less welcome now than last year
# 50767                                                     NaN
# 2782                  Just as welcome now as I felt last year
# ...                                                       ...
# 57419                   A lot more welcome now than last year
# 49757                Somewhat more welcome now than last year
# 41608                Somewhat more welcome now than last year
# 33385       Not applicable - I did not use Stack Overflow ...
# 6716                  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 39258       Tech articles written by other developers;Indu...  26.0    Man
# 63129               Tech articles written by other developers   NaN    NaN
# 85715       Tech articles written by other developers;Indu...  28.0    Man
# 50767                                                     NaN   NaN    NaN
# 2782                                                      NaN  60.0    Man
# ...                                                       ...   ...    ...
# 57419       Tech articles written by other developers;Indu...  29.0    Man
# 49757       Tech articles written by other developers;Tech...  22.0    Man
# 41608       Tech articles written by other developers;Indu...  24.0    Man
# 33385                                                     NaN   NaN    NaN
# 6716        Tech articles written by other developers;Tech...  36.0    Man
#
#            Trans                Sexuality                     Ethnicity  \
# Respondent
# 39258         No  Straight / Heterosexual        East Asian;South Asian
# 63129        NaN                      NaN                           NaN
# 85715         No                      NaN                           NaN
# 50767        NaN                      NaN                           NaN
# 2782         NaN                      NaN                           NaN
# ...          ...                      ...                           ...
# 57419         No  Straight / Heterosexual  White or of European descent
# 49757         No  Straight / Heterosexual  White or of European descent
# 41608         No  Straight / Heterosexual  White or of European descent
# 33385        NaN                      NaN                           NaN
# 6716          No  Straight / Heterosexual  White or of European descent
#
#            Dependents           SurveyLength                  SurveyEase
# Respondent
# 39258             Yes               Too long                        Easy
# 63129             Yes              Too short                        Easy
# 85715             Yes               Too long  Neither easy nor difficult
# 50767             NaN                    NaN                         NaN
# 2782              NaN  Appropriate in length                        Easy
# ...               ...                    ...                         ...
# 57419              No              Too short  Neither easy nor difficult
# 49757             Yes               Too long                        Easy
# 41608             Yes  Appropriate in length                        Easy
# 33385             NaN                    NaN                         NaN
# 6716              Yes  Appropriate in length                        Easy
#
# [50 rows x 84 columns]

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending=False, inplace=True)
df.head(50)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 55405                          I am a developer by profession      Yes
# 76594                          I am a developer by profession       No
# 83850                          I am a developer by profession       No
# 15299                          I am a developer by profession      Yes
# 15930       I am not primarily a developer, but I write co...      Yes
# ...                                                       ...      ...
# 54236       I am not primarily a developer, but I write co...       No
# 65793                          I am a developer by profession      Yes
# 73166       I am not primarily a developer, but I write co...      Yes
# 21289                             I code primarily as a hobby      Yes
# 33908                             I code primarily as a hobby      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 55405                                                   Never
# 76594                                                   Never
# 83850       Less than once a month but more than once per ...
# 15299                                                   Never
# 15930                                 Less than once per year
# ...                                                       ...
# 54236                                                   Never
# 65793                                 Less than once per year
# 73166                                 Less than once per year
# 21289                                                   Never
# 33908                                                   Never
#
#                                                    OpenSource  \
# Respondent
# 55405       OSS is, on average, of LOWER quality than prop...
# 76594       The quality of OSS and closed source software ...
# 83850       OSS is, on average, of LOWER quality than prop...
# 15299       The quality of OSS and closed source software ...
# 15930       The quality of OSS and closed source software ...
# ...                                                       ...
# 54236       The quality of OSS and closed source software ...
# 65793       OSS is, on average, of LOWER quality than prop...
# 73166       The quality of OSS and closed source software ...
# 21289       The quality of OSS and closed source software ...
# 33908                                                     NaN
#
#                                                    Employment   Country  \
# Respondent
# 55405                                      Employed full-time  Zimbabwe
# 76594                                      Employed full-time  Zimbabwe
# 83850                                      Employed full-time  Zimbabwe
# 15299       Independent contractor, freelancer, or self-em...  Zimbabwe
# 15930                                      Employed full-time  Zimbabwe
# ...                                                       ...       ...
# 54236                                      Employed part-time    Zambia
# 65793       Independent contractor, freelancer, or self-em...    Zambia
# 73166       Independent contractor, freelancer, or self-em...    Zambia
# 21289                  Not employed, and not looking for work    Zambia
# 33908                  Not employed, and not looking for work    Zambia
#
#                    Student                                            EdLevel  \
# Respondent
# 55405       Yes, part-time  Some college/university study without earning ...
# 76594                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83850                   No  Some college/university study without earning ...
# 15299                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 15930                   No  Some college/university study without earning ...
# ...                    ...                                                ...
# 54236                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 65793       Yes, part-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 73166                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 21289                   No  Some college/university study without earning ...
# 33908                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 55405       Computer science, computer engineering, or sof...
# 76594       Computer science, computer engineering, or sof...
# 83850       Another engineering discipline (ex. civil, ele...
# 15299                               Mathematics or statistics
# 15930                                                     NaN
# ...                                                       ...
# 54236       Computer science, computer engineering, or sof...
# 65793       Computer science, computer engineering, or sof...
# 73166       Another engineering discipline (ex. civil, ele...
# 21289       Another engineering discipline (ex. civil, ele...
# 33908       A social science (ex. anthropology, psychology...
#
#                                                      EduOther  ...  \
# Respondent                                                     ...
# 55405       Taken an online course in programming or softw...  ...
# 76594       Taken an online course in programming or softw...  ...
# 83850                                                     NaN  ...
# 15299       Taken an online course in programming or softw...  ...
# 15930       Taken an online course in programming or softw...  ...
# ...                                                       ...  ...
# 54236       Taken a part-time in-person course in programm...  ...
# 65793       Taken an online course in programming or softw...  ...
# 73166       Taught yourself a new language, framework, or ...  ...
# 21289       Taught yourself a new language, framework, or ...  ...
# 33908       Taught yourself a new language, framework, or ...  ...
#
#                                        WelcomeChange  \
# Respondent
# 55405        Just as welcome now as I felt last year
# 76594        Just as welcome now as I felt last year
# 83850       Somewhat less welcome now than last year
# 15299        Just as welcome now as I felt last year
# 15930        Just as welcome now as I felt last year
# ...                                              ...
# 54236        Just as welcome now as I felt last year
# 65793       Somewhat more welcome now than last year
# 73166        Just as welcome now as I felt last year
# 21289        Just as welcome now as I felt last year
# 33908          A lot more welcome now than last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 55405       Tech articles written by other developers;Indu...  33.0    Man
# 76594       Tech articles written by other developers;Cour...  33.0    Man
# 83850       Tech articles written by other developers;Indu...  23.0    Man
# 15299       Tech articles written by other developers;Indu...  35.0    Man
# 15930                                                     NaN  41.0    Man
# ...                                                       ...   ...    ...
# 54236       Tech articles written by other developers;Tech...  26.0    Man
# 65793       Tech articles written by other developers;Indu...  28.0    Man
# 73166       Tech articles written by other developers;Indu...   NaN    Man
# 21289       Tech articles written by other developers;Indu...  23.0    Man
# 33908       Tech articles written by other developers;Indu...  49.0    Man
#
#            Trans                Sexuality                    Ethnicity  \
# Respondent
# 55405         No  Straight / Heterosexual  Black or of African descent
# 76594         No  Straight / Heterosexual  Black or of African descent
# 83850         No  Straight / Heterosexual  Black or of African descent
# 15299         No  Straight / Heterosexual  Black or of African descent
# 15930         No  Straight / Heterosexual  Black or of African descent
# ...          ...                      ...                          ...
# 54236         No  Straight / Heterosexual  Black or of African descent
# 65793        Yes  Straight / Heterosexual  Black or of African descent
# 73166         No  Straight / Heterosexual                          NaN
# 21289         No  Straight / Heterosexual  Black or of African descent
# 33908         No                 Bisexual  Black or of African descent
#
#            Dependents           SurveyLength                  SurveyEase
# Respondent
# 55405             Yes  Appropriate in length  Neither easy nor difficult
# 76594             Yes               Too long  Neither easy nor difficult
# 83850             Yes               Too long                        Easy
# 15299             Yes               Too long                        Easy
# 15930             Yes  Appropriate in length                        Easy
# ...               ...                    ...                         ...
# 54236              No  Appropriate in length  Neither easy nor difficult
# 65793              No  Appropriate in length  Neither easy nor difficult
# 73166              No  Appropriate in length  Neither easy nor difficult
# 21289              No               Too long                        Easy
# 33908             Yes  Appropriate in length                        Easy
#
# [50 rows x 84 columns]
